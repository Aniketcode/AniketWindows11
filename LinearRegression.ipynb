# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketcode/AniketWindows11/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X=np.array([1,2,3,4,5,6,7])
Y=np.array([1.5,3.8,6.7,9.0,11.2,13.6,16])
print(X)
print(Y)
# Out:
# [1 2 3 4 5 6 7]
# [ 1.5  3.8  6.7  9.  11.2 13.6 16. ]

# %%
X=X.reshape(-1,1)
print(X)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]
#  [7]]

# %%
X.shape
# Out:
# (7, 1)

# %%
plt.scatter(X,Y,color="red")
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Scatter Plot")
plt.show()

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
r_square=model.score(X,Y)

# %%
print('Determinat of Coefficient',r_square)
# Out:
# Determinat of Coefficient 0.99896818873402

# %%
print('Slope: ',model.coef_)
# Out:
# Slope:  [2.41428571]

# %%
print('Intercept: ',model.intercept_)
# Out:
# Intercept:  -0.8285714285714274

# %%
y_pred=model.predict(X)

# %%
print('Predicted response: ',y_pred)
print('Actual value: ',Y)
# Out:
# Predicted response:  [ 1.58571429  4.          6.41428571  8.82857143 11.24285714 13.65714286
#  16.07142857]
# Actual value:  [ 1.5  3.8  6.7  9.  11.2 13.6 16. ]

# %%
plt.scatter(X,Y,color="red")
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.title("Scatter Plot")
plt.plot(X,y_pred,color="green")
plt.show()

# %%
plt.scatter(X,Y,color="red")
plt.xlabel("Target value")
plt.ylabel("Predicted value")
plt.title("Simple Linear Model")
plt.plot(X,y_pred,color="green")
plt.show()

# %%
#Mean absolute error
#mean square error

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(Y,y_pred)
mse=mean_squared_error(Y,y_pred)
rmse=np.sqrt(mse)
print(mae)
# Out:
# 0.13061224489795928

# %%
print(f'Mean absolute error: {mae:.4f}')
print(f'mean square error: {mse:.4f}')
print(f'Root mean square error: {rmse:.4f}')
# Out:
# Mean absolute error: 0.1306
# mean square error: 0.0241
# Root mean square error: 0.1552
